# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics

X = np.array([[1,1],[1.1,1.1],[1.2,1.2],
             [2,2],[2.1,2.1],[2.2,2.2]])
y = [1,1,1,
     0,0,0]
kmeans = KMeans(n_clusters=2,random_state=0).fit(X)

print("集群中心的座標",kmeans.cluster_centers_)
print("預測:",kmeans.predict(X))
print("實際:",y)
print("預測[1,1],[2.3,2.1]",kmeans.predict([[1,1],[2.3,2.1]]))

plt.axis([0, 3, 0, 3])
plt.plot(X[:3,0], X[:3,1], 'yx')
plt.plot(X[3:,0], X[3:,1], 'g.')
plt.plot(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 'ro')
plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# 集群中心的座標 [[2.1 2.1]
#  [1.1 1.1]]
# 預測: [1 1 1 0 0 0]
# 實際: [1, 1, 1, 0, 0, 0]
# 預測[1,1],[2.3,2.1] [1 0]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn import metrics

iris = datasets.load_iris()

iris_X_train , iris_X_test , iris_y_train , iris_y_test = train_test_split(iris.data,iris.target,test_size=0.2)

kmeans = KMeans(n_clusters = 3)
kmeans_fit = kmeans.fit(iris_X_train)

print("實際",iris_y_train)
print("預測",kmeans_fit.labels_)

iris_y_train[iris_y_train==1]=11
iris_y_train[iris_y_train==0]=1
iris_y_train[iris_y_train==11]=0
print("調整",iris_y_train)

score = metrics.accuracy_score(iris_y_train,kmeans.predict(iris_X_train))
print('準確率:{0:f}'.format(score))
# Out:
# 實際 [1 0 0 1 2 2 1 2 2 0 0 2 2 1 0 1 2 1 1 0 1 1 1 1 2 1 1 1 1 2 0 1 0 1 0 0 2
#  0 0 0 2 1 1 0 0 1 2 1 1 2 0 0 0 2 0 2 0 2 1 1 2 2 1 2 0 2 0 1 1 1 0 2 1 0
#  0 1 2 0 0 0 2 0 1 2 0 1 1 0 1 1 1 0 2 1 2 2 2 0 1 0 0 2 1 0 2 1 2 1 0 2 1
#  1 0 1 2 1 1 1 0 2]
# 預測 [0 1 1 0 2 2 0 2 0 1 1 2 2 0 1 0 2 0 0 1 0 0 0 0 2 0 0 2 0 2 1 0 1 0 1 1 2
#  1 1 1 2 0 0 1 1 0 2 0 0 2 1 1 1 2 1 2 1 0 0 2 2 2 0 2 1 0 1 0 0 0 1 2 0 1
#  1 0 2 1 1 1 2 1 0 0 1 0 0 1 2 0 0 1 2 2 2 2 2 1 0 1 1 2 0 1 2 0 2 0 1 2 0
#  0 1 0 2 0 0 2 1 0]
# 調整 [0 1 1 0 2 2 0 2 2 1 1 2 2 0 1 0 2 0 0 1 0 0 0 0 2 0 0 0 0 2 1 0 1 0 1 1 2
#  1 1 1 2 0 0 1 1 0 2 0 0 2 1 1 1 2 1 2 1 2 0 0 2 2 0 2 1 2 1 0 0 0 1 2 0 1
#  1 0 2 1 1 1 2 1 0 2 1 0 0 1 0 0 0 1 2 0 2 2 2 1 0 1 1 2 0 1 2 0 2 0 1 2 0
#  0 1 0 2 0 0 0 1 2]
# 準確率:0.916667

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn import metrics

iris = datasets.load_iris()

iris_X_train , iris_X_test , iris_y_train , iris_y_test = train_test_split(iris.data,iris.target,test_size=0.2)

kmeans = KMeans(n_clusters = 3)
kmeans.fit(iris_X_train)
y_predict = kmeans.predict(iris_X_train)

x1 = iris_X_train[:,0]
y1 = iris_X_train[:,1]
plt.scatter(x1,y1,c=y_predict,cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:,0],centers[:,1],c='black',s=200,alpha=0.5)
plt.show()

# %%
#找另外種算法去找另一種分類算法
#iris dataset decision tree
#有什麼差異

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Parameters
n_classes = 3
plot_colors = "ryb"
plot_step = 0.02

# Load data
iris = load_iris()

for pairidx, pair in enumerate([[0, 1], [0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
    # We only take the two corresponding features
    X = iris.data[:, pair]
    y = iris.target

    # Train
    clf = DecisionTreeClassifier().fit(X, y)

    # Plot the decision boundary
    plt.subplot(2, 3, pairidx + 1)

    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=0.5, w_pad=0.5, pad=2.5)

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)

    plt.xlabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])

    # Plot the training points
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y == i)
        plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
                    cmap=plt.cm.RdYlBu, edgecolor='black', s=15)

plt.suptitle("Decision surface of a decision tree using paired features")
plt.legend(loc='lower right', borderpad=0, handletextpad=0)
plt.axis("tight")

plt.figure()
clf = DecisionTreeClassifier().fit(iris.data, iris.target)
plot_tree(clf, filled=True)
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# > https://zhuanlan.zhihu.com/p/74271672
# ## 決策樹
# 優勢：可解釋性高；能處理非線性數據；不需要對數據歸一化；可以用於特徵工程，特徵選擇；對數據分佈沒有偏好；廣泛應用；易於軟件實現；可以轉化為規則；
#
# 弱點：啟發式生成，不是最優解；容易過擬合；微小的數據改變會改變整個樹的形狀；對類別不平衡的數據不友好。
#
# ## K-means
# K值需要預先給定，屬於預先知識，很多情況下K值的估計是非常困難的，對於像計算全部微信用戶的交往圈這樣的場景就完全的沒辦法用K-Means進行。對於可以確定K值不會太大但不明確精確的K值的場景，可以進行迭代運算，然後找出Cost Function最小時所對應的K值，這個值往往能較好的描述有多少個簇類。
#
# K-Means算法對初始選取的聚類中心點是敏感的，不同的隨機種子點得到的聚類結果完全不同

# %%
"""
    神經網路
    A simple neural network written in Keras (TensorFlow backend) to classify the IRIS data
"""

import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

iris_data = load_iris() # load the iris dataset

print('Example data: ')
print(iris_data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Example data:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Example labels:
# [0 0 0 0 0]
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                50
# _________________________________________________________________
# fc2 (Dense)                  (None, 10)                110
# _________________________________________________________________
# output (Dense)               (None, 3)                 33
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 24/24 - 0s - loss: 1.1862 - accuracy: 0.6750
# Epoch 2/200
# 24/24 - 0s - loss: 1.1042 - accuracy: 0.6750
# Epoch 3/200
# 24/24 - 0s - loss: 1.0416 - accuracy: 0.6750
# Epoch 4/200
# 24/24 - 0s - loss: 0.9836 - accuracy: 0.6750
# Epoch 5/200
# 24/24 - 0s - loss: 0.9263 - accuracy: 0.6750
# Epoch 6/200
# 24/24 - 0s - loss: 0.8748 - accuracy: 0.6750
# Epoch 7/200
# 24/24 - 0s - loss: 0.8232 - accuracy: 0.6750
# Epoch 8/200
# 24/24 - 0s - loss: 0.7739 - accuracy: 0.6750
# Epoch 9/200
# 24/24 - 0s - loss: 0.7257 - accuracy: 0.6750
# Epoch 10/200
# 24/24 - 0s - loss: 0.6824 - accuracy: 0.6750
# Epoch 11/200
# 24/24 - 0s - loss: 0.6409 - accuracy: 0.6750
# Epoch 12/200
# 24/24 - 0s - loss: 0.6060 - accuracy: 0.6750
# Epoch 13/200
# 24/24 - 0s - loss: 0.5742 - accuracy: 0.6750
# Epoch 14/200
# 24/24 - 0s - loss: 0.5477 - accuracy: 0.7500
# Epoch 15/200
# 24/24 - 0s - loss: 0.5242 - accuracy: 0.8583
# Epoch 16/200
# 24/24 - 0s - loss: 0.5037 - accuracy: 0.9000
# Epoch 17/200
# 24/24 - 0s - loss: 0.4878 - accuracy: 0.8750
# Epoch 18/200
# 24/24 - 0s - loss: 0.4716 - accuracy: 0.9167
# Epoch 19/200
# 24/24 - 0s - loss: 0.4586 - accuracy: 0.8917
# Epoch 20/200
# 24/24 - 0s - loss: 0.4444 - accuracy: 0.9083
# Epoch 21/200
# 24/24 - 0s - loss: 0.4332 - accuracy: 0.9000
# Epoch 22/200
# 24/24 - 0s - loss: 0.4210 - accuracy: 0.9167
# Epoch 23/200
# 24/24 - 0s - loss: 0.4146 - accuracy: 0.8917
# Epoch 24/200
# 24/24 - 0s - loss: 0.4022 - accuracy: 0.9333
# Epoch 25/200
# 24/24 - 0s - loss: 0.3946 - accuracy: 0.9333
# Epoch 26/200
# 24/24 - 0s - loss: 0.3872 - accuracy: 0.9083
# Epoch 27/200
# 24/24 - 0s - loss: 0.3780 - accuracy: 0.9250
# Epoch 28/200
# 24/24 - 0s - loss: 0.3691 - accuracy: 0.9250
# Epoch 29/200
# 24/24 - 0s - loss: 0.3672 - accuracy: 0.9333
# Epoch 30/200
# 24/24 - 0s - loss: 0.3593 - accuracy: 0.9250
# Epoch 31/200
# 24/24 - 0s - loss: 0.3500 - accuracy: 0.9167
# Epoch 32/200
# 24/24 - 0s - loss: 0.3416 - accuracy: 0.9417
# Epoch 33/200
# 24/24 - 0s - loss: 0.3323 - accuracy: 0.9417
# Epoch 34/200
# 24/24 - 0s - loss: 0.3272 - accuracy: 0.9417
# Epoch 35/200
# 24/24 - 0s - loss: 0.3192 - accuracy: 0.9167
# Epoch 36/200
# 24/24 - 0s - loss: 0.3088 - accuracy: 0.9417
# Epoch 37/200
# 24/24 - 0s - loss: 0.3029 - accuracy: 0.9500
# Epoch 38/200
# 24/24 - 0s - loss: 0.2897 - accuracy: 0.9417
# Epoch 39/200
# 24/24 - 0s - loss: 0.2794 - accuracy: 0.9417
# Epoch 40/200
# 24/24 - 0s - loss: 0.2697 - accuracy: 0.9583
# Epoch 41/200
# 24/24 - 0s - loss: 0.2575 - accuracy: 0.9583
# Epoch 42/200
# 24/24 - 0s - loss: 0.2535 - accuracy: 0.9500
# Epoch 43/200
# 24/24 - 0s - loss: 0.2470 - accuracy: 0.9333
# Epoch 44/200
# 24/24 - 0s - loss: 0.2325 - accuracy: 0.9750
# Epoch 45/200
# 24/24 - 0s - loss: 0.2230 - accuracy: 0.9583
# Epoch 46/200
# 24/24 - 0s - loss: 0.2290 - accuracy: 0.9583
# Epoch 47/200
# 24/24 - 0s - loss: 0.2158 - accuracy: 0.9417
# Epoch 48/200
# 24/24 - 0s - loss: 0.2084 - accuracy: 0.9667
# Epoch 49/200
# 24/24 - 0s - loss: 0.2002 - accuracy: 0.9500
# Epoch 50/200
# 24/24 - 0s - loss: 0.1966 - accuracy: 0.9750
# Epoch 51/200
# 24/24 - 0s - loss: 0.1888 - accuracy: 0.9583
# Epoch 52/200
# 24/24 - 0s - loss: 0.1817 - accuracy: 0.9583
# Epoch 53/200
# 24/24 - 0s - loss: 0.1779 - accuracy: 0.9750
# Epoch 54/200
# 24/24 - 0s - loss: 0.1778 - accuracy: 0.9333
# Epoch 55/200
# 24/24 - 0s - loss: 0.1697 - accuracy: 0.9750
# Epoch 56/200
# 24/24 - 0s - loss: 0.1682 - accuracy: 0.9500
# Epoch 57/200
# 24/24 - 0s - loss: 0.1622 - accuracy: 0.9583
# Epoch 58/200
# 24/24 - 0s - loss: 0.1630 - accuracy: 0.9583
# Epoch 59/200
# 24/24 - 0s - loss: 0.1539 - accuracy: 0.9750
# Epoch 60/200
# 24/24 - 0s - loss: 0.1576 - accuracy: 0.9583
# Epoch 61/200
# 24/24 - 0s - loss: 0.1487 - accuracy: 0.9750
# Epoch 62/200
# 24/24 - 0s - loss: 0.1467 - accuracy: 0.9750
# Epoch 63/200
# 24/24 - 0s - loss: 0.1476 - accuracy: 0.9417
# Epoch 64/200
# 24/24 - 0s - loss: 0.1470 - accuracy: 0.9750
# Epoch 65/200
# 24/24 - 0s - loss: 0.1399 - accuracy: 0.9500
# Epoch 66/200
# 24/24 - 0s - loss: 0.1427 - accuracy: 0.9667
# Epoch 67/200
# 24/24 - 0s - loss: 0.1396 - accuracy: 0.9667
# Epoch 68/200
# 24/24 - 0s - loss: 0.1344 - accuracy: 0.9583
# Epoch 69/200
# 24/24 - 0s - loss: 0.1315 - accuracy: 0.9583
# Epoch 70/200
# 24/24 - 0s - loss: 0.1336 - accuracy: 0.9667
# Epoch 71/200
# 24/24 - 0s - loss: 0.1287 - accuracy: 0.9750
# Epoch 72/200
# 24/24 - 0s - loss: 0.1268 - accuracy: 0.9583
# Epoch 73/200
# 24/24 - 0s - loss: 0.1255 - accuracy: 0.9667
# Epoch 74/200
# 24/24 - 0s - loss: 0.1253 - accuracy: 0.9500
# Epoch 75/200
# 24/24 - 0s - loss: 0.1208 - accuracy: 0.9750
# Epoch 76/200
# 24/24 - 0s - loss: 0.1212 - accuracy: 0.9667
# Epoch 77/200
# 24/24 - 0s - loss: 0.1298 - accuracy: 0.9583
# Epoch 78/200
# 24/24 - 0s - loss: 0.1141 - accuracy: 0.9750
# Epoch 79/200
# 24/24 - 0s - loss: 0.1135 - accuracy: 0.9667
# Epoch 80/200
# 24/24 - 0s - loss: 0.1148 - accuracy: 0.9750
# Epoch 81/200
# 24/24 - 0s - loss: 0.1122 - accuracy: 0.9667
# Epoch 82/200
# 24/24 - 0s - loss: 0.1129 - accuracy: 0.9500
# Epoch 83/200
# 24/24 - 0s - loss: 0.1117 - accuracy: 0.9583
# Epoch 84/200
# 24/24 - 0s - loss: 0.1093 - accuracy: 0.9750
# Epoch 85/200
# 24/24 - 0s - loss: 0.1064 - accuracy: 0.9750
# Epoch 86/200
# 24/24 - 0s - loss: 0.1147 - accuracy: 0.9417
# Epoch 87/200
# 24/24 - 0s - loss: 0.1067 - accuracy: 0.9750
# Epoch 88/200
# 24/24 - 0s - loss: 0.1051 - accuracy: 0.9750
# Epoch 89/200
# 24/24 - 0s - loss: 0.1078 - accuracy: 0.9583
# Epoch 90/200
# 24/24 - 0s - loss: 0.1070 - accuracy: 0.9667
# Epoch 91/200
# 24/24 - 0s - loss: 0.1035 - accuracy: 0.9667
# Epoch 92/200
# 24/24 - 0s - loss: 0.1017 - accuracy: 0.9667
# Epoch 93/200
# 24/24 - 0s - loss: 0.1059 - accuracy: 0.9667
# Epoch 94/200
# 24/24 - 0s - loss: 0.1052 - accuracy: 0.9667
# Epoch 95/200
# 24/24 - 0s - loss: 0.1015 - accuracy: 0.9667
# Epoch 96/200
# 24/24 - 0s - loss: 0.0993 - accuracy: 0.9667
# Epoch 97/200
# 24/24 - 0s - loss: 0.1063 - accuracy: 0.9417
# Epoch 98/200
# 24/24 - 0s - loss: 0.1125 - accuracy: 0.9667
# Epoch 99/200
# 24/24 - 0s - loss: 0.0991 - accuracy: 0.9500
# Epoch 100/200
# 24/24 - 0s - loss: 0.1003 - accuracy: 0.9750
# Epoch 101/200
# 24/24 - 0s - loss: 0.0973 - accuracy: 0.9667
# Epoch 102/200
# 24/24 - 0s - loss: 0.0948 - accuracy: 0.9667
# Epoch 103/200
# 24/24 - 0s - loss: 0.0948 - accuracy: 0.9750
# Epoch 104/200
# 24/24 - 0s - loss: 0.1050 - accuracy: 0.9583
# Epoch 105/200
# 24/24 - 0s - loss: 0.0977 - accuracy: 0.9583
# Epoch 106/200
# 24/24 - 0s - loss: 0.0941 - accuracy: 0.9750
# Epoch 107/200
# 24/24 - 0s - loss: 0.0935 - accuracy: 0.9667
# Epoch 108/200
# 24/24 - 0s - loss: 0.1080 - accuracy: 0.9583
# Epoch 109/200
# 24/24 - 0s - loss: 0.1135 - accuracy: 0.9667
# Epoch 110/200
# 24/24 - 0s - loss: 0.0935 - accuracy: 0.9667
# Epoch 111/200
# 24/24 - 0s - loss: 0.0897 - accuracy: 0.9667
# Epoch 112/200
# 24/24 - 0s - loss: 0.0955 - accuracy: 0.9500
# Epoch 113/200
# 24/24 - 0s - loss: 0.0884 - accuracy: 0.9750
# Epoch 114/200
# 24/24 - 0s - loss: 0.0914 - accuracy: 0.9750
# Epoch 115/200
# 24/24 - 0s - loss: 0.0910 - accuracy: 0.9667
# Epoch 116/200
# 24/24 - 0s - loss: 0.0898 - accuracy: 0.9667
# Epoch 117/200
# 24/24 - 0s - loss: 0.0874 - accuracy: 0.9750
# Epoch 118/200
# 24/24 - 0s - loss: 0.0924 - accuracy: 0.9667
# Epoch 119/200
# 24/24 - 0s - loss: 0.0895 - accuracy: 0.9583
# Epoch 120/200
# 24/24 - 0s - loss: 0.0886 - accuracy: 0.9750
# Epoch 121/200
# 24/24 - 0s - loss: 0.0870 - accuracy: 0.9667
# Epoch 122/200
# 24/24 - 0s - loss: 0.0875 - accuracy: 0.9667
# Epoch 123/200
# 24/24 - 0s - loss: 0.0872 - accuracy: 0.9667
# Epoch 124/200
# 24/24 - 0s - loss: 0.0860 - accuracy: 0.9667
# Epoch 125/200
# 24/24 - 0s - loss: 0.0904 - accuracy: 0.9750
# Epoch 126/200
# 24/24 - 0s - loss: 0.0851 - accuracy: 0.9667
# Epoch 127/200
# 24/24 - 0s - loss: 0.0883 - accuracy: 0.9667
# Epoch 128/200
# 24/24 - 0s - loss: 0.0875 - accuracy: 0.9583
# Epoch 129/200
# 24/24 - 0s - loss: 0.0893 - accuracy: 0.9750
# Epoch 130/200
# 24/24 - 0s - loss: 0.0861 - accuracy: 0.9667
# Epoch 131/200
# 24/24 - 0s - loss: 0.0872 - accuracy: 0.9667
# Epoch 132/200
# 24/24 - 0s - loss: 0.0857 - accuracy: 0.9583
# Epoch 133/200
# 24/24 - 0s - loss: 0.0876 - accuracy: 0.9667
# Epoch 134/200
# 24/24 - 0s - loss: 0.0863 - accuracy: 0.9750
# Epoch 135/200
# 24/24 - 0s - loss: 0.0836 - accuracy: 0.9667
# Epoch 136/200
# 24/24 - 0s - loss: 0.0831 - accuracy: 0.9583
# Epoch 137/200
# 24/24 - 0s - loss: 0.0902 - accuracy: 0.9667
# Epoch 138/200
# 24/24 - 0s - loss: 0.0949 - accuracy: 0.9500
# Epoch 139/200
# 24/24 - 0s - loss: 0.0909 - accuracy: 0.9583
# Epoch 140/200
# 24/24 - 0s - loss: 0.0820 - accuracy: 0.9750
# Epoch 141/200
# 24/24 - 0s - loss: 0.0851 - accuracy: 0.9667
# Epoch 142/200
# 24/24 - 0s - loss: 0.0832 - accuracy: 0.9667
# Epoch 143/200
# 24/24 - 0s - loss: 0.0813 - accuracy: 0.9750
# Epoch 144/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9583
# Epoch 145/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9667
# Epoch 146/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9667
# Epoch 147/200
# 24/24 - 0s - loss: 0.0854 - accuracy: 0.9583
# Epoch 148/200
# 24/24 - 0s - loss: 0.0934 - accuracy: 0.9667
# Epoch 149/200
# 24/24 - 0s - loss: 0.0794 - accuracy: 0.9667
# Epoch 150/200
# 24/24 - 0s - loss: 0.0831 - accuracy: 0.9667
# Epoch 151/200
# 24/24 - 0s - loss: 0.0823 - accuracy: 0.9667
# Epoch 152/200
# 24/24 - 0s - loss: 0.0807 - accuracy: 0.9667
# Epoch 153/200
# 24/24 - 0s - loss: 0.0848 - accuracy: 0.9583
# Epoch 154/200
# 24/24 - 0s - loss: 0.0797 - accuracy: 0.9667
# Epoch 155/200
# 24/24 - 0s - loss: 0.0787 - accuracy: 0.9667
# Epoch 156/200
# 24/24 - 0s - loss: 0.0775 - accuracy: 0.9583
# Epoch 157/200
# 24/24 - 0s - loss: 0.0796 - accuracy: 0.9750
# Epoch 158/200
# 24/24 - 0s - loss: 0.0864 - accuracy: 0.9667
# Epoch 159/200
# 24/24 - 0s - loss: 0.0790 - accuracy: 0.9750
# Epoch 160/200
# 24/24 - 0s - loss: 0.0898 - accuracy: 0.9500
# Epoch 161/200
# 24/24 - 0s - loss: 0.0862 - accuracy: 0.9667
# Epoch 162/200
# 24/24 - 0s - loss: 0.0810 - accuracy: 0.9500
# Epoch 163/200
# 24/24 - 0s - loss: 0.0743 - accuracy: 0.9667
# Epoch 164/200
# 24/24 - 0s - loss: 0.0890 - accuracy: 0.9667
# Epoch 165/200
# 24/24 - 0s - loss: 0.0881 - accuracy: 0.9667
# Epoch 166/200
# 24/24 - 0s - loss: 0.0760 - accuracy: 0.9667
# Epoch 167/200
# 24/24 - 0s - loss: 0.0785 - accuracy: 0.9667
# Epoch 168/200
# 24/24 - 0s - loss: 0.0765 - accuracy: 0.9667
# Epoch 169/200
# 24/24 - 0s - loss: 0.0778 - accuracy: 0.9667
# Epoch 170/200
# 24/24 - 0s - loss: 0.0814 - accuracy: 0.9667
# Epoch 171/200
# 24/24 - 0s - loss: 0.0752 - accuracy: 0.9667
# Epoch 172/200
# 24/24 - 0s - loss: 0.0777 - accuracy: 0.9750
# Epoch 173/200
# 24/24 - 0s - loss: 0.0816 - accuracy: 0.9667
# Epoch 174/200
# 24/24 - 0s - loss: 0.0749 - accuracy: 0.9667
# Epoch 175/200
# 24/24 - 0s - loss: 0.0788 - accuracy: 0.9667
# Epoch 176/200
# 24/24 - 0s - loss: 0.0765 - accuracy: 0.9667
# Epoch 177/200
# 24/24 - 0s - loss: 0.0773 - accuracy: 0.9667
# Epoch 178/200
# 24/24 - 0s - loss: 0.0759 - accuracy: 0.9750
# Epoch 179/200
# 24/24 - 0s - loss: 0.0739 - accuracy: 0.9667
# Epoch 180/200
# 24/24 - 0s - loss: 0.0738 - accuracy: 0.9667
# Epoch 181/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9583
# Epoch 182/200
# 24/24 - 0s - loss: 0.0776 - accuracy: 0.9667
# Epoch 183/200
# 24/24 - 0s - loss: 0.0748 - accuracy: 0.9667
# Epoch 184/200
# 24/24 - 0s - loss: 0.0839 - accuracy: 0.9500
# Epoch 185/200
# 24/24 - 0s - loss: 0.0826 - accuracy: 0.9667
# Epoch 186/200
# 24/24 - 0s - loss: 0.0743 - accuracy: 0.9667
# Epoch 187/200
# 24/24 - 0s - loss: 0.0777 - accuracy: 0.9667
# Epoch 188/200
# 24/24 - 0s - loss: 0.0841 - accuracy: 0.9583
# Epoch 189/200
# 24/24 - 0s - loss: 0.0796 - accuracy: 0.9583
# Epoch 190/200
# 24/24 - 0s - loss: 0.0794 - accuracy: 0.9500
# Epoch 191/200
# 24/24 - 0s - loss: 0.0783 - accuracy: 0.9750
# Epoch 192/200
# 24/24 - 0s - loss: 0.0770 - accuracy: 0.9667
# Epoch 193/200
# 24/24 - 0s - loss: 0.0770 - accuracy: 0.9667
# Epoch 194/200
# 24/24 - 0s - loss: 0.0771 - accuracy: 0.9583
# Epoch 195/200
# 24/24 - 0s - loss: 0.0744 - accuracy: 0.9583
# Epoch 196/200
# 24/24 - 0s - loss: 0.0724 - accuracy: 0.9667
# Epoch 197/200
# 24/24 - 0s - loss: 0.0791 - accuracy: 0.9583
# Epoch 198/200
# 24/24 - 0s - loss: 0.0716 - accuracy: 0.9667
# Epoch 199/200
# 24/24 - 0s - loss: 0.0721 - accuracy: 0.9667
# Epoch 200/200
# 24/24 - 0s - loss: 0.0768 - accuracy: 0.9667
# 1/1 [==============================] - 0s 995us/step - loss: 0.0273 - accuracy: 1.0000
# Final test set loss: 0.027294
# Final test set accuracy: 1.000000
